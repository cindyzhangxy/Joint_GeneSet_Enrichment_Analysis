# %%
if (!require("tidyverse", quietly = TRUE)) {
  install.packages("tidyverse", quiet = TRUE, verbose = FALSE)
}

if (!require("stringr", quietly = TRUE)) {
  install.packages("stringr", quiet = TRUE, verbose = FALSE)
}

if (!require("data.table", quietly = TRUE)) {
  install.packages("data.table", quiet = TRUE, verbose = FALSE)
}

suppressPackageStartupMessages({
    library(tidyverse)
    library(stringr)
    library(data.table)
})
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.4.1      v purrr   1.0.0
# v tibble  3.2.0      v dplyr   1.0.10
# v tidyr   1.2.1      v stringr 1.5.0
# v readr   2.1.3      v forcats 0.5.2
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Attaching package: 'data.table'
#
#
# The following objects are masked from 'package:dplyr':
#
#     between, first, last
#
#
# The following object is masked from 'package:purrr':
#
#     transpose

# %% [markdown]
# #### Function to clean marker names

# %%
clean_marker <- function(marker) {
  marker <- tolower(marker)
  marker <- gsub("gsa-|seq-", "", marker)
  marker <- dplyr::recode(marker, "ilmnseq_6:35378798" = "rs9658134")
  return(marker)
}

# %% [markdown]
# #### Loading Data
# * variants used as features for GBDT
# * SNP-based GWAS logistic regression result

# %%
df <- fread("../feature_tsv/binary_feature_pruned_subject_removed.tsv")
colnames_df <- data.frame(variants = colnames(df)[1:260]) %>% 
  separate(., col = variants, into = c("gene", "MARKER"), sep = "_", remove=FALSE) %>% 
  select(MARKER)

snp <- fread("../admixture/variant_population/mtx_case_control_logistic_regression_result_09122023.tsv") %>% 
  select(-c(SNP,P) ) %>% 
  mutate(MARKER = clean_marker(MARKER))

setdiff(colnames_df$MARKER, snp$MARKER)
# Out:
# [1] "rs7761870"   "rs6457821"   "rs112012380" "rs3823433"   "rs6457813"
# [6] "rs9658134"

# %% [markdown]
# * The logistic regression data has MAF thus, filtered out low MAF. __--maf 0.01__, --geno 0.05, --hwe 0.000001 midp include-nonctrl, --mind 0.05  __GH__(exclude MAF < 0.01) :Methotrexate_QC_complete (ds102210)
#
#
# * The initial feature table contains variant that has __noMAF__ --geno 0.05, --hwe 0.000001 midp include-nonctrl, --mind 0.05, __No Genotype Harmonizer__ CPNDS_8.03_variant&sampleQC_complete_noMAF_noGH (ds102004)
#
# Cindy's speculation for the discrepancy:
#
# __Data Inconsistency__: If the case and control groups are from different platforms or sources, the SNP may be harmonized out if it doesn't appear consistently across all datasets?

# %%
snp <- snp %>%
inner_join(colnames_df) %>%
rename(OR = ORX, marker = MARKER, allele = A1)
# Out:
# Joining, by = "MARKER"

# %% [markdown]
# ##### Save table

# %%
write.table(snp, "../admixture/variant_population/snp_frequency_variant.tsv", row.names = FALSE)

# %% [markdown]
# #### Reload ensembl ancestry_allele_frequency table (python API)

# %%
ancestry_allele <- 
fread("../admixture/variant_population/ensembl_ancestry_allele_frequecy.tsv") %>% 
  distinct() %>% 
  mutate(population = str_replace(population, "1000GENOMES:phase_3:", "")) %>% 
  filter(population %in% c("AMR", "AFR", "EAS","EUR", "SAS") )

table(ancestry_allele$population)
# Out:
# AFR AMR EAS EUR SAS
# 498 507 458 508 499

# %%
ancestry_af <- snp %>% 
  left_join(ancestry_allele, by=c("marker", "allele")) %>% 
  pivot_wider(., names_from = population, values_from = frequency) %>%
  mutate(`effect allele`= case_when(
    OR > 1 ~ "increase risk",
    OR < 1 ~ "decrease risk",
    OR == 1 ~ "no effect" ))

# %% [markdown]
# #### Attach variants to  WNT or IL6 and the 6 genes PRKCD,PIK3R2, AGT, LRP5, CSNK1A1, PPARD: "5580, 5296, 183, 4041, 1452, 5467"

# %%
jagsetAnnot <- fread("../jag.set.annot.annot")
# covert all rsid to lower case
jagsetAnnot$V1 <- tolower(jagsetAnnot$V1)
# remove GSA- from colnames 
jagsetAnnot$V1 <- gsub("gsa-|seq-", "", jagsetAnnot$V1)
#change ilmnseq term
jagsetAnnot$V1[jagsetAnnot$V1 =="ilmnseq_6:35378798"] <- "rs9658134" 

jagsetAnnot <- jagsetAnnot %>%
  filter(V3 == "WNT" |V3 == "IL6") %>% 
  filter(V2 %in% c("5580", "5296", "183", "4041", "1452", "5467") ) %>% 
  mutate(symbols = case_when(
    grepl("5580", V2) ~ "PRKCD",
    grepl("5296", V2) ~ "PIK3R2",
    grepl("183", V2) ~ "AGT",
    grepl("4041", V2) ~ "LRP5",
    grepl("1452", V2) ~ "CSNK1A1",
    grepl("5467", V2) ~ "PPARD"
  ))

colnames(jagsetAnnot) <- c("marker", "entrezId", "pathways", "gene_symbols")

# %%
head(ancestry_af, 2)
# Out:
#   marker   allele OR    AFR        AMR       EAS       EUR       SAS
# 1 rs853463 T      1.199 0.42208775 0.4697406 0.4394841 0.4850895 0.3251534
# 2 rs853464 A      1.177 0.07791225 0.1080692 0.1984127 0.1312127 0.2423313
#   effect allele
# 1 increase risk
# 2 increase risk

# %%
# merge dataframes by rsid

ancestry_af <- left_join(ancestry_af, jagsetAnnot, by = "marker")

# %%
colnames(ancestry_af)
# Out:
#  [1] "marker"        "allele"        "OR"            "AFR"
#  [5] "AMR"           "EAS"           "EUR"           "SAS"
#  [9] "effect allele" "entrezId"      "pathways"      "gene_symbols"

# %%
population_cols = ancestry_af %>% 
select(c('AFR','AMR','EAS','EUR','SAS'))

ancestry_af %>% 
mutate(max_col = apply(population_cols, 1, function(x) names(population_cols)[which.max(x)]))
# Out:
#     marker      allele OR     AFR          AMR         EAS          EUR
# 1   rs853463    T      1.1990 0.4220877458 0.469740634 0.4394841270 0.48508946
# 2   rs853464    A      1.1770 0.0779122542 0.108069164 0.1984126984 0.13121272
# 3   rs78869074  G      0.9787 0.0052950076 0.033141210 0.0208333333 0.04970179
# 4   rs111776064 A      1.1580 0.0007564297 0.005763689           NA 0.02087475
# 5   rs77645389  T      0.7444 0.0007564297 0.023054755           NA 0.03379722
# 234 rs2072490   C      1.3210 0.6520423601 0.475504323 0.3204365079 0.498011928
# 235 rs375947    G      1.0470 0.2367624811 0.175792507 0.3759920635 0.313121272
# 236 rs11666281  T      0.9754 0.1762481089 0.171469741 0.1071428571 0.251491054
# 237 rs271828    A      1.0520 0.5612708018 0.472622478 0.7867063492 0.367793241
# 238 rs10411949  G      1.0130 0.7753403933 0.448126801 0.5337301587 0.450298211
# 239 rs999813    T      0.8823 0.6875945537 0.603746398 0.5535714286 0.466202783
# 240 rs62120362  C      1.1580 0.0098335855 0.072046110 0.0119047619 0.157057654
# 241 rs271834    A      0.8216 0.4243570348 0.417867435 0.5585317460 0.482107356
# 242 rs412133    T      1.1590 0.1724659607 0.325648415 0.0595238095 0.270377734
# 243 rs56020911  C      1.0280 0.2564296520 0.337175793 0.5942460317 0.365805169
# 244 rs3803919   G      0.7385 0.1875945537 0.321325648 0.0912698413 0.366799205
# 245 rs12462974  C      0.7887 0.4296520424 0.128242075 0.0128968254 0.028827038
# 246 rs372889    C      0.9628 0.5211800303 0.311239193 0.3799603175 0.525844930
# 247 rs2305743   A      0.6997 0.1860816944 0.109510086 0.1051587302 0.198807157
# 248 rs172043    A      0.8770 0.0166414523 0.217579251 0.1428571429 0.342942346
# 249 rs3730179   A      1.1410 0.1762481089 0.275216138 0.1865079365 0.409542744
# 250 rs874628    G      1.1400 0.1966717095 0.197406340 0.0654761905 0.281312127
# 251 rs11670370  T      1.1150 0.2314674735 0.296829971 0.0714285714 0.296222664
# 252 rs117648604 T      1.8190 0.0022692890 0.010086455           NA 0.018886680
# 253 rs56022120  T      5.0840 0.0015128593 0.093659942 0.0386904762 0.013916501
# 254 rs79268593  C      1.3320 0.0007564297 0.023054755 0.0009920635 0.047713718
#     SAS         effect allele entrezId pathways gene_symbols max_col
# 1   0.325153374 increase risk 183      IL6      AGT          EUR
# 2   0.242331288 increase risk 183      IL6      AGT          SAS
# 3   0.076687117 decrease risk 183      IL6      AGT          SAS
# 4   0.003067485 increase risk 183      IL6      AGT          EUR
# 5   0.021472393 decrease risk 183      IL6      AGT          EUR
# 6   0.275051125 increase risk 183      IL6      AGT          AFR
# 7   0.063394683 decrease risk 183      IL6      AGT          EAS
# 8   0.392638037 increase risk 183      IL6      AGT          EUR
# 9   0.095092025 decrease risk 183      IL6      AGT          EAS
# 10  0.326175869 increase risk 183      IL6      AGT          EUR
# 11  0.195296524 increase risk 183      IL6      AGT          SAS
# 12  0.189161554 decrease risk 183      IL6      AGT          AFR
# 13  0.216768916 increase risk 183      IL6      AGT          AMR
# 14  0.169734151 decrease risk 183      IL6      AGT          EUR
# 15  0.398773006 decrease risk 183      IL6      AGT          EAS
# 16  0.002044990 increase risk 183      IL6      AGT          EUR
# 17  0.040899796 decrease risk 183      IL6      AGT          EUR
# 18  0.081799591 decrease risk 183      IL6      AGT          EAS
# 19  0.031697342 decrease risk 183      IL6      AGT          SAS
# 20  0.095092025 increase risk 183      IL6      AGT          AFR
# 21  0.066462168 increase risk 183      IL6      AGT          AMR
# 22  0.083844581 increase risk 183      IL6      AGT          EAS
# 23  0.313905930 decrease risk 183      IL6      AGT          EUR
# 24  0.084867076 increase risk 183      IL6      AGT          EUR
# 25  0.330265849 increase risk 183      IL6      AGT          EUR
# 26  0.011247444 increase risk 183      IL6      AGT          EUR
# 27  0.056237219 increase risk 183      IL6      AGT          AMR
# 28  0.001022495 increase risk 183      IL6      AGT          EUR
# 29  0.288343558 increase risk 183      IL6      AGT          EUR
# 30  0.538854806 decrease risk 183      IL6      AGT          AFR
# <U+22EE>   <U+22EE>    <U+22EE>      <U+22EE> <U+22EE> <U+22EE>     <U+22EE>
# 225 0.003067485 decrease risk 4041     WNT      LRP5         EUR
# 226 0.007157464 increase risk 5296     IL6      PIK3R2       EUR
# 227 0.007157464 increase risk 5296     IL6      PIK3R2       EUR
# 228 0.473415133 increase risk 5296     IL6      PIK3R2       AFR
# 229 0.098159509 increase risk 5296     IL6      PIK3R2       EAS
# 230 0.004089980 decrease risk 5296     IL6      PIK3R2       EUR
# 231 0.223926380 increase risk 5296     IL6      PIK3R2       AMR
# 232          NA increase risk 5296     IL6      PIK3R2       EUR
# 233 0.011247444 decrease risk 5296     IL6      PIK3R2       EUR
# 234 0.301635992 increase risk 5296     IL6      PIK3R2       AFR
# 235 0.220858896 increase risk 5296     IL6      PIK3R2       EAS
# 236 0.123721881 decrease risk 5296     IL6      PIK3R2       EUR
# 237 0.656441718 increase risk 5296     IL6      PIK3R2       EAS
# 238 0.353783231 increase risk 5296     IL6      PIK3R2       AFR
# 239 0.414110429 decrease risk 5296     IL6      PIK3R2       AFR
# 240 0.027607362 increase risk 5296     IL6      PIK3R2       EUR
# 241 0.440695297 decrease risk 5296     IL6      PIK3R2       EAS
# 242 0.162576687 increase risk 5296     IL6      PIK3R2       AMR
# 243 0.323108384 increase risk 5296     IL6      PIK3R2       EAS
# 244 0.148261759 decrease risk 5296     IL6      PIK3R2       EUR
# 245 0.039877301 decrease risk 5296     IL6      PIK3R2       AFR
# 246 0.290388548 decrease risk 5296     IL6      PIK3R2       EUR
# 247 0.109406953 decrease risk 5296     IL6      PIK3R2       EUR
# 248 0.169734151 decrease risk 5296     IL6      PIK3R2       EUR
# 249 0.156441718 increase risk 5296     IL6      PIK3R2       EUR
# 250 0.131901840 increase risk 5296     IL6      PIK3R2       EUR
# 251 0.174846626 increase risk 5296     IL6      PIK3R2       AMR
# 252 0.026584867 increase risk 5296     IL6      PIK3R2       SAS
# 253 0.056237219 increase risk 5296     IL6      PIK3R2       AMR
# 254 0.005112474 increase risk 5296     IL6      PIK3R2       EUR

# %%
write.csv(ancestry_af, "../feature_tsv/ancestry_allele_frequency/ancestry_allele_frequency.tsv")
